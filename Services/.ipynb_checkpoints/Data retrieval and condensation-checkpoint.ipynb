# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# %%
import re
import pandas as pd

# %%
# Use a service account
cred = credentials.Certificate('key/oduFireKey.json')
firebase_admin.initialize_app(cred)

db = firestore.client()

# %%
bookings_ref = db.collection(u'Bookings')
routes_ref = db.collection(u'Bus Routes')
stops_ref = db.collection(u'Bus Stops')

bookings_firebaseGenerator = bookings_ref.stream()
routes_firebaseGenerator = routes_ref.stream()
stops_firebaseGenerator = stops_ref.stream()

# %%
bookings = [doc.to_dict() for doc in bookings_firebaseGenerator]
routes = [doc.to_dict() for doc in routes_firebaseGenerator]
stops = [doc.to_dict() for doc in stops_firebaseGenerator]

# %%
routes[0]
# Out:
# {'Route': 'Bypass - Vennala - Vyttila',
#  'Route_id': '100',
#  'Start': 'Bypass',
#  'End': 'Vyttila'}

# %%
bookings[0]
# Out:
# {'Bus Type': 'Fast Passenger',
#  'Timing': '2 - 6',
#  'Booking ID': '288295',
#  'Phone Number': '9867260140',
#  'Fare': 31,
#  'To': 'KOTTAYAM BS (KTM)',
#  'From': 'PALA (PLA)',
#  'Booking Time': DatetimeWithNanoseconds(2020, 4, 10, 13, 10, 31, 119000, tzinfo=<UTC>),
#  'UID': 'qn6n9nzNHrQlC6kcIcSVx5lubSq1'}

# %%
stops[0]['Stop Name']
# Out:
# 'ILANJIYAM'

# %%
routes_df = pd.DataFrame(routes)
bookings_df = pd.DataFrame(bookings)
stops_df = pd.DataFrame(stops)
# routes_df.iloc[:,[4]]
routes_df
# Out:
#                                                Route Route_id           Start  \
# 0                         Bypass - Vennala - Vyttila      100          Bypass
# 1         Medical Trust - South - Menaka - Highcourt      101   Medical Trust
# 2                        Palarivattom - Lulu - Aluva      102    Palarivattom
# 3                 Palarivattom - Thammanam - Vyttila      103    Palarivattom
# 4            Palarivattom - Kaloor - South - Vyttila      104    Palarivattom
# 5                  Pala - Bharananganam - Erattupeta      105            Pala
# 6  Pathanamthitta - Mekozhoor - Vayalathala- Keek...      106  Pathanamthitta
# 7  Kottayam - Ettumanoor - Pala - Neeloor - Araku...      107        Kottayam
# 8    hodupuzha - Erattupeta - Muttom - Kanjirappalli      108      Thodupuzha
# 9   Aluva - Angamaly - Chalakudy - Konikkara - Th...      109           Aluva
#
#              End
# 0        Vyttila
# 1      Highcourt
# 2          Aluva
# 3        Vyttila
# 4        Vyttila
# ...

# %%
bookings_df
# Out:
#          Bus Type  Timing Booking ID Phone Number  Fare  \
# 0  Fast Passenger   2 - 6     288295   9867260140    31
# 1     Super Dulex  6 - 10     326739   9867260140    32
# 2  Fast Passenger  6 - 10     372644   9867260140    42
# 3  Fast Passenger  6 - 10     402167   9867260140    43
# 4        Ordinary  6 - 11     452259   7012835996   227
# 5  Fast Passenger  6 - 10     486446   9867260140    56
# 6        Ordinary  6 - 10     508326   7012835996    49
# 7      Super Fast  10 - 2     709793   9867260140    36
# 8   Super Express  6 - 10     917497   7012835996    72
# 9  Fast Passenger   2 - 6     971774   9867260140    30
#
#                         To                    From  \
# 0        KOTTAYAM BS (KTM)              PALA (PLA)
# 1                    KOCHI              PALA (PLA)
# 2           ADOOR BS (ADR)  CHANGANASSERY BS (CHR)
# 3            BHARANANGANAM  CHANGANASSERY BS (CHR)
# 4  GOKULAM MEDICAL COLLEGE              ALIPARAMBA
# ...

# %%
stops_df.loc[:10,["Stop Name"]]
# Out:
#                   Stop Name
# 0                 ILANJIYAM
# 1              ELAVUMTHITTA
# 2              THOOKKUPALAM
# 3   KANJIKKUZHY (ALAPPUZHA)
# 4                NADUVANNUR
# 5                  THENKARA
# 6                  PALAYODE
# 7                   LAKKIDI
# 8            MAKKARAPARAMBA
# 9      AANAPPARA (ANGAMALY)
# 10                SIVAPURAM

# %%
pattern = r"([\w]+)[ [\w]+]?"

# %%
bool(re.match("ILANJ",stops[0]["Stop Name"]))
# Out:
# True

# %%
[s["Stop Name"] for s in stops if(bool(re.match(pattern,s["Stop Name"])))]
# Out:
# ['ILANJIYAM',
#  'ELAVUMTHITTA',
#  'THOOKKUPALAM',
#  'KANJIKKUZHY (ALAPPUZHA)',
#  'NADUVANNUR',
#  'THENKARA',
#  'PALAYODE',
#  'LAKKIDI',
#  'MAKKARAPARAMBA',
#  'AANAPPARA (ANGAMALY)',
#  'SIVAPURAM',
#  'SN PURAM (NEDUMANGAD)',
#  'KURUMBALAKOTTA',
#  'CHAMRAVATTOM',
#  'THALAPPAADI',
#  'THEKKADA',
#  'METHALA',
#  'KACHANI',
#  'KONNAKKALKADAVU',
#  'MUNAB',
#  'PARAKKULAM',
#  'VELI',
#  'KALLUVATHUKKAL',
#  'CHULLIMANOOR',
#  'RAJAGIRI',
#  'DASANAKKARA',
#  'PERAMBRA ESTATE',
#  'KADAMURUTTI',
#  'KURUPPAMPADY',
#  'CHAL BEACH',
#  'VALLITHODE',
#  'MULLASSERY',
#  'KURAMPALA',
#  'PANAMBUKADU',
#  'CENTRAL POLYTECHNIC',
#  'POOCHAPRA',
#  'ANAYADI',
#  'VENGAD',
#  'PILLAPPARA',
#  'BLATHOOR',
#  'THALAYOLAPARAMBU',
#  'ERUMAMUNDA',
#  'KOLLUR MOOKAMBIKA TEMPLE',
#  'KESAVADASAPURAM',
#  'CHATHANNOOR',
#  'MANJIKADU',
#  'KOLLADU',
#  'THATHAPPILLY',
#  'ALAPPUZHA',
#  'ARATTUPUZHA',
#  'MANAKADAVU',
#  'VALIYAVELICHAM',
#  'KOZHUVANA (BATHERY)',
#  'CHENDAMANGALAM',
# ...

# %%
stops_df["Stop Name(cleaned)"] = stops_df["Stop Name"].str.extract(pattern)
stops_df["Stop Name(cleaned)"]
# Out:
# 0          ILANJIYA
# 1       ELAVUMTHITT
# 2       THOOKKUPALA
# 3       KANJIKKUZHY
# 4         NADUVANNU
#            ...
# 2273     KOTTAPURAM
# 2274        THENKAS
# 2275        ELAMKAD
# 2276    PALLIKATHOD
# 2277      VALANCHER
# Name: Stop Name(cleaned), Length: 2278, dtype: object

# %%
bookings_df["To (cleaned)"] = bookings_df["To"].str.extract(pattern)
bookings_df["From (cleaned)"] = bookings_df["From"].str.extract(pattern)
bookings_df
# Out:
#          Bus Type  Timing Booking ID Phone Number  Fare  \
# 0  Fast Passenger   2 - 6     288295   9867260140    31
# 1     Super Dulex  6 - 10     326739   9867260140    32
# 2  Fast Passenger  6 - 10     372644   9867260140    42
# 3  Fast Passenger  6 - 10     402167   9867260140    43
# 4        Ordinary  6 - 11     452259   7012835996   227
# 5  Fast Passenger  6 - 10     486446   9867260140    56
# 6        Ordinary  6 - 10     508326   7012835996    49
# 7      Super Fast  10 - 2     709793   9867260140    36
# 8   Super Express  6 - 10     917497   7012835996    72
# 9  Fast Passenger   2 - 6     971774   9867260140    30
#
#                         To                    From  \
# 0        KOTTAYAM BS (KTM)              PALA (PLA)
# 1                    KOCHI              PALA (PLA)
# 2           ADOOR BS (ADR)  CHANGANASSERY BS (CHR)
# 3            BHARANANGANAM  CHANGANASSERY BS (CHR)
# 4  GOKULAM MEDICAL COLLEGE              ALIPARAMBA
# ...

# %%
stops_df[stops_df["Stop Name(cleaned)"].str.match("VYTILLA")]
# Out:
#               Stop Name                                        Case Search  \
# 1977  VYTILLA HUB (VMH)  [V, VY, VYT, VYTI, VYTIL, VYTILL, VYTILLA, VYT...
#
#      Stop Name(cleaned)
# 1977            VYTILLA

# %%
def check(row):
#     re.match(str(row),routes_df['Start'])
    print(row)

# %%
bookings_df["To (cleaned)"].apply(check)
# Out:
# KOTTAYAM
# KOCH
# ADOOR
# BHARANANGANA
# GOKULAM
# KOCH
# PALA
# KOTTAYAM
# KOCH
# PALA
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# 9    None
# Name: To (cleaned), dtype: object
